# %%
122. Best Time to Buy and Sell Stock II
Medium
Topics
premium lock icon
Companies
You are given an integer array prices where prices[i] is the price of a given stock on the ith day.

On each day, you may decide to buy and/or sell the stock. You can only hold at most one share of the stock at any time. However, you can sell and buy the stock multiple times on the same day, ensuring you never hold more than one share of the stock.

Find and return the maximum profit you can achieve.

 

Example 1:

Input: prices = [7,1,5,3,6,4]
Output: 7
Explanation: Buy on day 2 (price = 1) and sell on day 3 (price = 5), profit = 5-1 = 4.
Then buy on day 4 (price = 3) and sell on day 5 (price = 6), profit = 6-3 = 3.
Total profit is 4 + 3 = 7.
Example 2:

Input: prices = [1,2,3,4,5]
Output: 4
Explanation: Buy on day 1 (price = 1) and sell on day 5 (price = 5), profit = 5-1 = 4.
Total profit is 4.
Example 3:

Input: prices = [7,6,4,3,1]
Output: 0
Explanation: There is no way to make a positive profit, so we never buy the stock to achieve the maximum profit of 0.
 

Constraints:

1 <= prices.length <= 3 * 104
0 <= prices[i] <= 104

# %%
prices = [7,1,5,3,6,4]

prices = [1,2,3,4,5]

# %%
left = 0
right = 1
profit = 0

# %%
for x in range(len(prices)):
    prices_short = prices[x:]
    if len(prices_short)>1 and prices_short[left]<prices_short[right]:
        profit = profit + (prices_short[right] - prices_short[left])
        left+=1
        right+=1
    left = 0
    right = 1

# %%
profit
# Out:
# 4

# %%
#prices = [10000, 10000, 10000, 10000]
# prices = [0, 6, 7, 534, 4, 4, 4, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 57]
# prices = [7, 7, 4, 4, 4, 4, 4, 48, 8, 8, 4, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 644, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 65, 754, 2, 5, 4, 4, 44, 4, 4, 4, 4, 4, 4, 4, 4, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 4, 324, 4, 41, 132, 1, 1, 155, 1, 155, 1, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 4, 324, 4, 41, 132, 1, 1, 155, 1, 155, 1, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 4, 324, 4, 41, 132, 1, 1, 155, 1, 155, 1, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354]
# prices = [1, 1, 1, 7, 4, 4, 4223, 4, 4, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 4, 324, 4, 41, 132, 1, 1, 155, 1, 155, 1, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 4, 324, 4, 41, 132, 1, 1, 155, 1, 155, 1, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 4, 324, 4, 41, 132, 1, 1, 155, 1, 155, 1, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 4, 324, 4, 41, 132, 1, 1, 155, 1, 155, 1, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 4, 324, 4, 41, 132, 1, 1, 155, 1, 155, 1]
# prices = [2, 1, 4, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 54, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 64, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 20, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 5, 8, 5624, 47, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 56, 24, 743, 2, 4, 3243, 44, 4, 132, 543, 7, 4, 4, 4, 4, 4, 4, 4, 4, 4343, 643, 423, 100, 132, 5434, 4, 4, 4, 4, 42, 1, 0, 1, 200, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 64, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 20, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 5, 8, 5624, 47, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 56, 24, 743, 2, 4, 3243, 44, 4, 132, 543, 7, 4, 4, 4, 4, 4, 4, 4, 4, 4343, 643, 423, 100, 132, 5434, 4, 4, 4, 4, 42, 1, 0, 1, 200, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 64, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 20, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 5, 8, 5624, 47, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 56, 24, 743, 2, 4, 3243, 44, 4, 132, 543, 7, 4, 4, 4, 4, 4, 4, 4, 4, 4343, 643, 423, 100, 132, 5434, 4, 4, 4, 4, 42, 1, 0, 1, 200, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 64, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 20, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 5, 8, 5624, 47, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 56, 24, 743, 2, 4, 3243, 44, 4, 132, 543, 7, 4, 4, 4, 4, 4, 4, 4, 4, 4343, 643, 423, 100, 132, 5434, 4, 4, 4, 4, 42, 1, 0, 1, 200]
# prices = [1000, 10, 4, 455, 4, 4, 4, 44, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 430, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 430, 75, 7650, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 320, 234, 50, 104, 320, 0, 0, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 430, 75, 7650, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 320, 234, 50, 104, 320, 0, 0, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 430, 75, 7650, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 320, 234, 50, 104, 320, 0, 0, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 430, 75, 7650, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 320, 234, 50, 104, 320, 0, 0, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 430, 75, 7650, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 320, 234, 50, 104, 320, 0, 0, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 430, 75, 7650, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 320, 234, 50, 104, 320, 0, 0, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 4, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 430, 75, 7650, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 320, 234, 50, 104, 320, 0, 0]
prices = [100, 132, 543, 7, 4, 4, 44, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 21, 41, 4, 5, 5465, 8, 54, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 647, 4, 4, 4, 4, 4, 4, 4, 4, 43, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 107, 4, 454, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 35, 4, 4, 5354, 4, 4533, 4, 40, 132, 543, 343, 643, 423, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 647, 4, 4, 4, 4, 4, 4, 4, 4, 43, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 107, 4, 454, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 35, 4, 4, 5354, 4, 4533, 4, 40, 132, 543, 343, 643, 423, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 647, 4, 4, 4, 4, 4, 4, 4, 4, 43, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 107, 4, 454, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 35, 4, 4, 5354, 4, 4533, 4, 40, 132, 543, 343, 643, 423, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 647, 4, 4, 4, 4, 4, 4, 4, 4, 43, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 107, 4, 454, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 35, 4, 4, 5354, 4, 4533, 4, 40, 132, 543, 343, 643, 423, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 647, 4, 4, 4, 4, 4, 4, 4, 4, 43, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 107, 4, 454, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 35, 4, 4, 5354, 4, 4533, 4, 40, 132, 543, 343, 643, 423, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 647, 4, 4, 4, 4, 4, 4, 4, 4, 43, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 107, 4, 454, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 35, 4, 4, 5354, 4, 4533, 4, 40, 132, 543, 343, 643, 423, 34, 437, 557, 687, 69, 454, 35, 457, 8658, 4543, 546, 46, 466, 323, 86, 65, 8, 5624, 34, 4, 4, 4, 4, 4, 4343, 643, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 647, 4, 4, 4, 4, 4, 4, 4, 4, 43, 423, 100, 132, 543, 343, 643, 423, 100, 132, 543, 343, 643, 423, 107, 4, 454, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 35, 4, 4, 5354, 4, 4533, 4, 40, 132, 543, 343, 643, 423, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354, 455, 4, 4, 4, 44, 3, 1343, 2, 343, 654, 763, 57, 65, 876, 34, 436, 6, 435, 45, 54, 87, 656, 4, 4, 45, 32, 65, 2, 6466, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 66, 43, 75, 765, 235, 547, 34, 45, 7, 34, 760, 0, 0, 0, 45, 45, 5, 12, 365, 697, 433, 45, 4, 5, 43, 5, 323, 86, 65, 8, 5624, 2, 42, 325, 4354]

# %%
from typing import List

# %%
class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        left = 0
        right = 1
        profit = 0
        for x in range(len(prices)):
            prices_short = prices[x:]
            if len(prices_short)>1 and prices_short[left]<prices_short[right]:
                profit = profit + (prices_short[right] - prices_short[left])
                left+=1
                right+=1
            left = 0
            right = 1
        return profit

# %%
cv = Solution()

# %%
cv.maxProfit(prices)
# Out:
# 784486

# %%
class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        total_profit = 0
        for i in range(1, len(prices)):
            day_profit = prices[i] - prices[i-1]
            if day_profit > 0:
                total_profit += day_profit

        return total_profit

# %%
class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        min_price = float('inf')
        max_profit = 0
        for x in prices:
            min_price = min(min_price, x)
            profit = x - min_price
            max_profit = max(max_profit, profit)
        return max_profit
