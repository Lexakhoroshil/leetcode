# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dict_phone = {  2:['a','b','c'],
                3:['d','e','f'],
                4:['g','h','i'],
                5:['j','k','l'],
                6:['m','n','o'],
                7:['p','q','r','s'],
                8:['t','u','v'],
                9:['w','x','y','z']
                }

# %%
class Solution:
    def letterCombinations(self, digits: str) -> List[str]:

# %%
digits = "237"
split_digits = [int(x) for x in digits]
split_digits
# Out:
# [2, 3, 7]

# %%
for pos in split_digits:

# %%
digits = "23"
split_digits = [int(x) for x in digits]

combinations_array =[]
if len(digits)>1:
    for digit in split_digits:
        array_one = dict_phone[digit]
        combinations_array.append(array_one)

# %%
combinations_array
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f']]

# %%
new_combo = []

# %%
print(combinations_array[0][0] + combinations_array[1][0])
print(combinations_array[0][0] + combinations_array[1][1])
print(combinations_array[0][0] + combinations_array[1][2])

print(combinations_array[0][1] + combinations_array[1][0])
print(combinations_array[0][1] + combinations_array[1][1])
print(combinations_array[0][1] + combinations_array[1][2])


print(combinations_array[0][2] + combinations_array[1][0])
print(combinations_array[0][2] + combinations_array[1][1])
print(combinations_array[0][2] + combinations_array[1][2])
# Out:
# ad
# ae
# af
# bd
# be
# bf
# cd
# ce
# cf

# %%
digits = "237"
split_digits = [int(x) for x in digits]

combinations_array =[]
if len(digits)>1:
    for digit in split_digits:
        array_one = dict_phone[digit]
        combinations_array.append(array_one)

# %%
combinations_array
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f'], ['p', 'q', 'r', 's']]

# %%
for digit in digits:
    c = dict_phone[int(digit)]
    for item in c:
        print(item, dict_phone)
# Out:
# ['a', 'b', 'c']
# ['d', 'e', 'f']
# ['p', 'q', 'r', 's']

# %%
new_list = []
for first_symb in combinations_array[0]:
    new_str=""
    i=0
    for others in combinations_array[1:]:
        k=0
        while k<len(others):
            new_str = first_symb + others[i]
            new_list.append(new_str)
            k+=1

# %%
new_list
# Out:
# ['ad',
#  'ad',
#  'ad',
#  'ap',
#  'ap',
#  'ap',
#  'ap',
#  'bd',
#  'bd',
#  'bd',
#  'bp',
#  'bp',
#  'bp',
#  'bp',
#  'cd',
#  'cd',
#  'cd',
#  'cp',
#  'cp',
#  'cp',
#  'cp']

# %%
print(combinations_array[0][0] + combinations_array[1][0] + combinations_array[2][0])
print(combinations_array[0][0] + combinations_array[1][1] + combinations_array[2][0])
print(combinations_array[0][0] + combinations_array[1][2] + combinations_array[2][0])

print(combinations_array[0][0] + combinations_array[1][0] + combinations_array[2][1])
print(combinations_array[0][0] + combinations_array[1][1] + combinations_array[2][1])
print(combinations_array[0][0] + combinations_array[1][2] + combinations_array[2][1])

print(combinations_array[0][0] + combinations_array[1][0] + combinations_array[2][2])
print(combinations_array[0][0] + combinations_array[1][1] + combinations_array[2][2])
print(combinations_array[0][0] + combinations_array[1][2] + combinations_array[2][2])

print(combinations_array[0][0] + combinations_array[1][0] + combinations_array[2][3])
print(combinations_array[0][0] + combinations_array[1][1] + combinations_array[2][3])
print(combinations_array[0][0] + combinations_array[1][2] + combinations_array[2][3])
# Out:
# adp
# aep
# afp
# adq
# aeq
# afq
# adr
# aer
# afr
# ads
# aes
# afs

# %%
i = 0
j = 0

while i<len(combinations_array)-1:
    while j<len(combinations_array[i]):
        print(combinations_array[i, j])
        i+=1
        j+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 6
#       4 while i<len(combinations_array)-1:
#       5     while j<len(combinations_array[i]):
# ----> 6         print(combinations_array[i, j])
#       7         i+=1
#       8         j+=1
#
# TypeError: list indices must be integers or slices, not tuple

# %%
i = 0
l = []
while i <len(combinations_array):
    for j in combinations_array[i]:
        l.append(j)
    i+=1

# %%
l
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'j', 'k', 'l']

# %%
i = 0
while i <len(combinations_array):
    for j in combinations_array[i]:
        k = i +1
        if k <len(combinations_array):
            print(j, combinations_array[k:] )
    i+=1
# Out:
# a [['d', 'e', 'f'], ['j', 'k', 'l']]
# b [['d', 'e', 'f'], ['j', 'k', 'l']]
# c [['d', 'e', 'f'], ['j', 'k', 'l']]
# d [['j', 'k', 'l']]
# e [['j', 'k', 'l']]
# f [['j', 'k', 'l']]

# %%
split_digits
# Out:
# [2, 3, 5]

# %%
split_digits
# Out:
# [2, 3]

# %%
digits
# Out:
# '23'

# %%
dict_phone = {  2:'abc',
                3:'def',
                4:'ghi',
                5:'jkl',
                6:'mno',
                7:'pqrs',
                8:'tuv',
                9:'wxyz'
                }

# %%
dict_phone
# Out:
# {2: 'abc',
#  3: 'def',
#  4: 'ghi',
#  5: 'jkl',
#  6: 'mno',
#  7: 'pqrs',
#  8: 'tuv',
#  9: 'wxyz'}
