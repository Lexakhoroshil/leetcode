# %%
Given an array of integers citations where citations[i] is the number of citations a researcher received for their ith paper, return the researcher's h-index.

According to the definition of h-index on Wikipedia: The h-index is defined as the maximum value of h such that the given researcher has published at least h papers that have each been cited at least h times.

 

Example 1:

Input: citations = [3,0,6,1,5]
Output: 3
Explanation: [3,0,6,1,5] means the researcher has 5 papers in total and each of them had received 3, 0, 6, 1, 5 citations respectively.
Since the researcher has 3 papers with at least 3 citations each and the remaining two with no more than 3 citations each, their h-index is 3.
Example 2:

Input: citations = [1,3,1]
Output: 1

# %%
citations = [3,0,6, 6,1,5]

l = len(citations)

# %%
citations = [10,10,10,10,10,10, 10, 10, 10, 5]

# %%
for j in citations:
    for i in range(l-1):
        if citations[i]<citations[i+1]:
            citations[i], citations[i+1]  = citations[i+1],citations[i]

# %%
min(citations[l//2], len(citations))
# Out:
# 10

# %%
citations
# Out:
# [10, 10, 10, 10, 10, 10, 10, 10, 10, 0]

# %%
citations = [3,0,6, 6,1,5]

citations = [10,10,10,10,10,10, 10, 10, 10, 5]
citations = [2, 2, 0]
l = len(citations)
min_value = min(citations)
max_value = max(citations)

if max_value <1:
    print(0)
else:

    while l > min_value:
        citations.pop(citations.index(min_value))
        min_value = min(citations)
        print(citations, l)
        l = len(citations)
    print(len(citations))
# Out:
# [2, 2] 3
# 2

# %%
l
# Out:
# 2

# %%
l
# Out:
# 2

# %%
from typing import List

# %%
citations = [3,0,6, 6,1,5]

# %%
class Solution:
    def hIndex(self, citations: List[int]) -> int:

        l = len(citations)
        min_value = min(citations)
        max_value = max(citations)

        if max_value <1:
            return 0
        else:
            while l > min_value:
                citations.pop(citations.index(min_value))
                min_value = min(citations)
                l = len(citations)
            return len(citations)

# %%
cv= Solution()

# %%
cv.hIndex(citations)
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# решение из литкода оптимальное
class Solution:
    def hIndex(self, citations: List[int]) -> int:
        n = len(citations)
        bucket = [0]*(n+1)
        for c in citations:
            if c >= n:
                bucket[n] += 1
            else:
                bucket[c] += 1
        count = 0
        for i in range(n,-1,-1):
            count += bucket[i]
            if count >= i:
                return i
        return 0 #check for all, ì dont sastify any return 0

# %%
class Solution:
    def hIndex(self, citations: List[int]) -> int:
        citations.(reverse=True)

        h = 0
        for i, c in enumerate(citations, 1):
            if i <= c:
                h = i
            else:
                break
        
        return h
