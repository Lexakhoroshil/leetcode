# %%
Given a string s, return the longest palindromic substring in s.

 

Example 1:

Input: s = "babad"
Output: "bab"
Explanation: "aba" is also a valid answer.
Example 2:

Input: s = "cbbd"
Output: "bb"
 

Constraints:

1 <= s.length <= 1000
s consist of only digits and English letters.

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:

# %%
# идея через половинки: пока не допер как реализовать
s = "babad"

if len(s)%2 == 1:
    mid_position = int((len(s) - 1)/2)

center = s[mid_position]
right_half = s[:mid_position]
left_half = s[mid_position+1:]
for i in right_half

# %%
# простой брутфорс
s = "babadbaaaaaaaab"

# %%
s[0:]
# Out:
# 'babadbaaaaaaaab'

# %% [markdown]
# # Попытка 1

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:
        l_ = []
        s_left = ""
        s_right = ""
        for pos, symb in enumerate(s): #enumerate(s[1:]):
            s_left = s[:pos]
            s_right = s[pos+1:]
            print(s_left)
            print(s_right)
            if s_left == s_left[::-1]:
                
                l_.append(s_left)
            if s_right == s_right[::-1]:
                l_.append(s_right)
                
        return max(l_, key=len)

# %%
s ="babab"
cv = Solution()
cv.longestPalindrome(s)
# Out:
# abab
# b
# bab
# ba
# ab
# bab
# b
# baba
# 'bab'

# %%
s = "cbbd"
cv = Solution()
cv.longestPalindrome(s)
# Out:
# bbd
# c
# bd
# cb
# d
# cbb
# 'c'

# %%
# неправильно отработало

# %%
# попробуем сделать это без хранения в памяти массивов
# через указатели и с учетом четные и нечетные

# %%
s ="babab"
s = "cbbd"

# %%
max_s_init = 0

for i, _ in enumerate(s):
    max_s = 0
    print('----', i, '----')
    if len(s)%2 ==1:
        r = l = i
    else:
        l=i
        r=i+1
    while (l>=0 and r <len(s) and s[l] == s[r]):
        max_s = max(max_s, r-l+1)
        max_s_init = max(max_s_init,max_s)
        print(l,r, max_s)
        if max_s == max_s_init:
            l_fin = l
            r_fin = r
        l -=1
        r+= 1
if len(s)%2 ==1:
    palindr = s[l_fin:r_fin-1]     
else:
    palindr = s[l_fin:r_fin]
# Out:
# ---- 0 ----
# ---- 1 ----
# 1 2 2
# ---- 2 ----
# ---- 3 ----

# %%
palindr
# Out:
# 'b'

# %%
'ac'[:2]
# Out:
# 'ac'

# %% [markdown]
# # Попытка 2

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:
        if len(s) <= 1:
            return s
        if 1<len(s) <= 2:
            if s != s[::-1]:
                return s[:1]

        max_s_init = 0
    
        for i, _ in enumerate(s):
            max_s = 0
            #print('----', i, '----')
            if len(s)%2 ==1:
                r = l = i
            else:
                l=i
                r=i+1
            while (l>=0 and r <len(s) and s[l] == s[r]):
                max_s = max(max_s, r-l+1)
                max_s_init = max(max_s_init,max_s)
                #print(l,r, max_s)
                if max_s == max_s_init:
                    l_fin = l
                    r_fin = r
                l -=1
                r+= 1
        # if len(s)%2 ==1:
        #     palindr = s[l_fin:r_fin+1]     
        # else:
        #     palindr = s[l_fin:r_fin+1]
        return  s[l_fin:r_fin+1]

# %%
cv = Solution()
cv.longestPalindrome('babad')
# Out:
# 'aba'

# %%
cv = Solution()
cv.longestPalindrome('cbbd')
# Out:
# 'bb'

# %%
cv = Solution()
cv.longestPalindrome('bbbbb')
# Out:
# 'bbbbb'

# %%
cv = Solution()
cv.longestPalindrome('bob')
# Out:
# 'bob'

# %%
cv = Solution()
cv.longestPalindrome('ac')
# Out:
# 'a'

# %%
s =
"ac"

# %%
s = "abb"

# %%
cv = Solution()
cv.longestPalindrome('abb')
# Out:
# 'b'

# %%
# мда заебался

# %%
# разобрать решение

https://www.youtube.com/watch?v=IrD8MA054vA

# %%
# попытка через 2 указателя

# %%
Example 1:

Input: s = "babad"
Output: "bab"
Explanation: "aba" is also a valid answer.
Example 2:

Input: s = "cbbd"
Output: "bb"
 

Constraints:

1 <= s.length <= 1000
s consist of only digits and English letters.

# %%
s = 'cbbd'

# %%
s[left]
# Out:
# 'c'

# %%
s ="babad"
#s = 'cbbd'
s = "bbbbbb"
s = "babab"

s = "xabay"
s= 'bob'
s = 'b'
s = 'ac'
s = "..."

# %%
l = ""
left = 0
right = len(s)-1

while left <= right:
   if s[left] != s[right]:
      left +=1
   if s[left] != s[right]:
      left -=1
      right -=1
   if s[left] == s[right]:
      l = str(left)+ ',' +l 
      l = l + str(right) +','
      left += 1
      right -=1
   print(left, right)
    

positions = sorted(int(x) for x in list(set((l.split(','))[:-1])))
s[min(positions): max(positions)+1]
# Out:
# 1 998
# 2 997
# 3 996
# 4 995
# 5 994
# 6 993
# 7 992
# 8 991
# 9 990
# 10 989
# 11 988
# 12 987
# 13 986
# 14 985
# 15 984
# 16 983
# 17 982
# 18 981
# 19 980
# 20 979
# 21 978
# 22 977
# 23 976
# 24 975
# 25 974
# 26 973
# 27 972
# 28 971
# 29 970
# 30 969
# 31 968
# 32 967
# 33 966
# 34 965
# 35 964
# 36 963
# 37 962
# 38 961
# 39 960
# 40 959
# 41 958
# 42 957
# 43 956
# 44 955
# 45 954
# 46 953
# 47 952
# 48 951
# 49 950
# 50 949
# 51 948
# 52 947
# 53 946
# 54 945
# 55 944
# 56 943
# 57 942
# 58 941
# 59 940
# 60 939
# 61 938
# 62 937
# 63 936
# 64 935
# 65 934
# 66 933
# 67 932
# 68 931
# 69 930
# 70 929
# 71 928
# 72 927
# 73 926
# 74 925
# 75 924
# 76 923
# 77 922
# 78 921
# 79 920
# 80 919
# 81 918
# 82 917
# 83 916
# 84 915
# 85 914
# 86 913
# 87 912
# 88 911
# 89 910
# 90 909
# 91 908
# 92 907
# 93 906
# 94 905
# 95 904
# 96 903
# 97 902
# 98 901
# 99 900
# 100 899
# 101 898
# 102 897
# 103 896
# 104 895
# 105 894
# 106 893
# 107 892
# 108 891
# 109 890
# 110 889
# ...

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:

        l = ""
        left = 0
        right = len(s)-1

        while left <= right:
           if s[left] != s[right]:
              left +=1
           if s[left] != s[right]:
              left -=1
              right -=1
           if s[left] == s[right]:
              l = str(left)+ ',' +l 
              l = l + str(right) +','
              left += 1
              right -=1


        positions = sorted(int(x) for x in list(set((l.split(','))[:-1])))
        return s[min(positions): max(positions)+1]

# %%
cv = Solution()

# %%
cv.longestPalindrome("cbbd")
# Out:
# 'bb'

# %%
"babaaaaaad"

c and d

b and d

c and b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 3
#       1 'cbbd'
# ----> 3 c and d
#       5 b and d
#       7 c and b
#
# NameError: name 'c' is not defined

# %%
 упало на abbcccba

# %%
s = "ab bccc ba"

# %%
l = ""
left = 0
right = len(s)-1
counter = 0
while left < right:
   if s[left] != s[right]:
      print(left, right)
      left +=1
      if s[left] != s[right]:
         left -=1
         right -=1
   l = ''

   if s[left] == s[right]:
      counter +=4
      l = str(left)+ ',' +l 
      l = l + str(right) +','
      left += 1
      right -=1
   
    

positions = sorted(int(x) for x in list(set((l.split(','))[:-1])))
s[min(positions): max(positions)+1]
# Out:
# 2 5
# 'ccc'

# %%
positions
# Out:
# [0, 1, 3, 5, 6, 7]

# %%
max_s = max(positions)
max_s
# Out:
# 7

# %%
min_s = min(positions)

# %%
list_t = [ x for x in range(min_s, max_s +1, 1)]

# %%
list_t
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
l[:-2]
# Out:
# '3,'

# %%
# разобрал свой код на примере abbcccba (ab bccc ba) - ошибка очевидна

# %%
Approach 1: Check All Substrings
Intuition

We can start with a brute-force approach. We will simply check if each substring is a palindrome, and take the longest one that is.

First, let's talk about how we can check if a given string is a palindrome. This is a classic problem and we can do it using two pointers. If a string is a palindrome, the first character is equal to the last character. The second character is equal to the second last character, and so on.

Palindrome Check

We initialize two pointers: one at the start of the string and another at the end of it. We check if the characters at the pointers are equal - if they aren't, we know the string cannot be a palindrome. If they are equal, we move to the next pair of characters by moving the pointers toward each other. We continue until we either find a mismatch or the pointers meet. If the pointers meet, then we have checked all pairs and we know the string is a palindrome.

One bonus to using this algorithm is that we frequently exit early on strings that are not palindromes. If you had a string of length 1000 and the third and third last characters did not match, we would exit the algorithm after only 3 iterations.

There's another optimization that we can do. Because the problem wants the longest palindrome, we can start by checking the longest-length substrings and iterate toward the shorter-length substrings. This way, the first time we find a substring that is a palindrome, we can immediately return it as the answer.

Algorithm

Create a helper method check(i, j) to determine if a substring is a palindrome.
To save space, we will not pass the substring itself. Instead, we will pass two indices that represent the substring in question. The first character will be s[i] and the last character will be s[j - 1].
In this function, declare two pointers left = i and right = j - 1.
While left < right, do the following steps:
If s[left] != s[right], return false.
Otherwise, increment left and decrement right.
If we get through the while loop, return true.
Use a for loop to iterate a variable length starting from s.length until 1. This variable represents the length of the substrings we are currently considering.
Use a for loop to iterate a variable start starting from 0 until and including s.length - length. This variable represents the starting point of the substring we are currently considering.
In each inner loop iteration, we are considering the substring starting at start until start + length. Pass these values into check to see if this substring is a palindrome. If it is, return the substring.

# %%
s = 'abbcccba'

# %%
def check(i, j):
    left = i
    right = j-1

    while left < right:
        if s[left]!=s[right]:
            return False
        
        left += 1
        right -= 1

    return True

# %%
    
for length in range(len(s), 0, -1):
    for start in range(len(s) - length +1):
        if check(start, start + length):
            print(s[start : start + length])
# Out:
# bcccb
# ccc
# bb
# cc
# cc
# a
# b
# b
# c
# c
# c
# b
# a

# %%
d
# Out:
# 'a'

# %%
s
# Out:
# 'abbcccba'

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:
        def check(s, i, j ):
            left = i
            right = j - 1

            while left < right:
                if s[left] != s[right]:
                    return False

                left += 1
                right -= 1

            return True

        for length in range(len(s), 0, -1):
            for start in range(len(s) - length + 1):
                if check(s, start, start + length):
                    return s[start : start + length]

        return ""

# %%
cv = Solution()

# %%
cv.longestPalindrome(s)
# Out:
# 'bcccb'

# %%
# вернуться к этой задаче, попробовать оптимизировать

class Solution:
    def longestPalindrome(self, s: str) -> str:
        def check(s, i, j ):
            left = i
            right = j - 1

            while left < right:
                if s[left] != s[right]:
                    return False

                left += 1
                right -= 1

            return True

        for length in range(len(s), 0, -1):
            for start in range(len(s) - length + 1):
                if check(s, start, start + length):
                    return s[start : start + length]

        return ""
