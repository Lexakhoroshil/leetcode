# %%
Given an integer array nums sorted in non-decreasing order, remove some duplicates in-place such that each unique element appears at most twice. The relative order of the elements should be kept the same.

Since it is impossible to change the length of the array in some languages, you must instead have the result be placed in the first part of the array nums. More formally, if there are k elements after removing the duplicates, then the first k elements of nums should hold the final result. It does not matter what you leave beyond the first k elements.

Return k after placing the final result in the first k slots of nums.

Do not allocate extra space for another array. You must do this by modifying the input array in-place with O(1) extra memory.

Custom Judge:

The judge will test your solution with the following code:

int[] nums = [...]; // Input array
int[] expectedNums = [...]; // The expected answer with correct length

int k = removeDuplicates(nums); // Calls your implementation

assert k == expectedNums.length;
for (int i = 0; i < k; i++) {
    assert nums[i] == expectedNums[i];
}
If all assertions pass, then your solution will be accepted.

 

Example 1:

Input: nums = [1,1,1,2,2,3]
Output: 5, nums = [1,1,2,2,3,_]
Explanation: Your function should return k = 5, with the first five elements of nums being 1, 1, 2, 2 and 3 respectively.
It does not matter what you leave beyond the returned k (hence they are underscores).
Example 2:

Input: nums = [0,0,1,1,1,1,2,3,3]
Output: 7, nums = [0,0,1,1,2,3,3,_,_]
Explanation: Your function should return k = 7, with the first seven elements of nums being 0, 0, 1, 1, 2, 3 and 3 respectively.
It does not matter what you leave beyond the returned k (hence they are underscores).
 

Constraints:

1 <= nums.length <= 3 * 104
-104 <= nums[i] <= 104
nums is sorted in non-decreasing order.

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        counter = 0
        hashmap = []
        for item in nums:
            if item not in hashmap:
                nums[counter] = item
                counter += 1
                hashmap.append(item)
        return counter

# %%
class Solution:
    def removeElement(self, nums: List[int], val: int) -> int:
        counter = 0
        for item in nums:
            if item != val:
                nums[counter] = item
                counter += 1
        return counter

# %%
nums = [1,1,1,2,2,3]
Output: 5, nums = [1,1,2,2,3,_]

# %%
nums = [1,1,1,2,2,3]

left = 0
right = len(nums) - 1

# %%
nums = [1,1,1,2,2,3]
counter_global = 0
counter_local = 0
left = 0
right = 1

# %%
val =1

# %%
for item in nums:
    if item != val:
        nums[counter] = item
        counter += 1

# %%
while left < len(nums)-1:
    counter_global += 1
    while nums[left] != nums[right]:
        counter_local += 1
        nums[left] = nums[right]
        left+=1
        right+=1
    right+=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[97], line 3
#       1 while left < len(nums)-1:
#       2     counter_global += 1
# ----> 3     while nums[left] != nums[right]:
#       4         counter_local += 1
#       5         nums[left] = nums[right]
#
# IndexError: list index out of range

# %%
nums
# Out:
# [2, 2, 3, 2, 2, 3]

# %%
counter_global
# Out:
# 3

# %%
counter_local
# Out:
# 3

# %%
nums = [1,1,1,2,2,3]
counter_global = 0
counter_local = 0
left = 0
right = 1

# %%
while left < len(nums)-1:
    
    if nums[left] == nums[right]:
        print('S')
        counter_local += 1
        if counter_local<2:
            counter_global+=1
            nums[left] = nums[left]
        else:
            counter_local = 0
            nums[left] = nums[right+1]
    left +=1
    right+=1
# Out:
# S
# S
# S

# %%
nums = [1,1,1,2,2,3]
counter_global = 0
counter_local = 0
left = 0
right = 1

# %%
from typing import List

# %%
nums = [1,1,1,2,2,3]

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        counter_global = 0
        counter_local = 0
        left = 0
        right = 1
        while left < len(nums)-1:
            print('----', nums, '-----')
            print('left', left, 'right', right, 'counter_local',counter_local)
            if nums[left] == nums[right]:
                counter_local +=1
                #fact = 'y'
                right +=1
                #print('left', left, nums[left], fact, counter_local)
            if counter_local>1:
            #nums[-1], nums[counter_local] = nums[counter_local],  nums[-1]
                nums.append(nums.pop(counter_local))
                counter_global+=1
                #right -=1

            if nums[left] != nums[right]:
                
                left+=1
                right = left+1
                counter_local = 0

            print('left', left, 'right', right, 'counter_local',counter_local)
        return len(nums) - counter_global

# %%
cv = Solution()
cv.removeDuplicates(nums = [0,0,1,1,1,1,2,3,3])
# Out:
# ---- [0, 0, 1, 1, 1, 1, 2, 3, 3] -----
# left 0 right 1 counter_local 0
# left 1 right 2 counter_local 0
# ---- [0, 0, 1, 1, 1, 1, 2, 3, 3] -----
# left 1 right 2 counter_local 0
# left 2 right 3 counter_local 0
# ---- [0, 0, 1, 1, 1, 1, 2, 3, 3] -----
# left 2 right 3 counter_local 0
# left 2 right 4 counter_local 1
# ---- [0, 0, 1, 1, 1, 1, 2, 3, 3] -----
# left 2 right 4 counter_local 1
# left 3 right 4 counter_local 0
# ---- [0, 0, 1, 1, 1, 2, 3, 3, 1] -----
# left 3 right 4 counter_local 0
# left 4 right 5 counter_local 0
# ---- [0, 0, 1, 1, 1, 2, 3, 3, 1] -----
# left 4 right 5 counter_local 0
# left 5 right 6 counter_local 0
# ---- [0, 0, 1, 1, 1, 2, 3, 3, 1] -----
# left 5 right 6 counter_local 0
# left 6 right 7 counter_local 0
# ---- [0, 0, 1, 1, 1, 2, 3, 3, 1] -----
# left 6 right 7 counter_local 0
# left 7 right 8 counter_local 0
# ---- [0, 0, 1, 1, 1, 2, 3, 3, 1] -----
# left 7 right 8 counter_local 0
# left 8 right 9 counter_local 0
# 8

# %%
nums = [0,0,1,1,1,1,2,3,3]
nums
# Out:
# [0, 0, 1, 1, 1, 1, 2, 3, 3]

# %%
counter = 2
for position in range(2, len(nums)):
    print('begin', position, nums)
    if nums[position] != nums[position-2]:
        #nums.append(nums.pop(position))
        nums[counter] = nums[position]
        counter+=1
    print('end', nums)
# Out:
# begin 2 [0, 0, 1, 1, 2, 3, 3, 3, 3]
# end [0, 0, 1, 1, 2, 3, 3, 3, 3]
# begin 3 [0, 0, 1, 1, 2, 3, 3, 3, 3]
# end [0, 0, 1, 1, 2, 3, 3, 3, 3]
# begin 4 [0, 0, 1, 1, 2, 3, 3, 3, 3]
# end [0, 0, 1, 1, 2, 3, 3, 3, 3]
# begin 5 [0, 0, 1, 1, 2, 3, 3, 3, 3]
# end [0, 0, 1, 1, 2, 3, 3, 3, 3]
# begin 6 [0, 0, 1, 1, 2, 3, 3, 3, 3]
# end [0, 0, 1, 1, 2, 3, 3, 3, 3]
# begin 7 [0, 0, 1, 1, 2, 3, 3, 3, 3]
# end [0, 0, 1, 1, 2, 3, 3, 3, 3]
# begin 8 [0, 0, 1, 1, 2, 3, 3, 3, 3]
# end [0, 0, 1, 1, 2, 3, 3, 3, 3]

# %%
nums
# Out:
# [0, 0, 1, 1, 2, 3, 3, 3, 3]

# %%
counter
# Out:
# 7

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        if len(nums)<3:
            return len(nums)

        counter = 2
        for position in range(2, len(nums)):
            #print('begin', position, nums)
            if nums[position] != nums[position-2]:
                #nums.append(nums.pop(position))
                nums[counter] = nums[position]
                counter+=1
        return counter

# %%
cv = Solution()
cv.removeDuplicates(nums = [0,0,1,1,1,1,2,3,3])
# Out:
# 7

# %%
nums
# Out:
# [0, 0, 1, 1, 2, 3, 3, 3, 3]

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        if len(nums)<3:
            return len(nums)

        counter = 2
        for position in range(2, len(nums)):
            #print('begin', position, nums)
            if nums[position] != nums[counter-2]:
                #nums.append(nums.pop(position))
                nums[counter] = nums[position]
                counter+=1
        return counter

# %%
cv = Solution()
cv.removeDuplicates(nums = [1,1,1,2,2,3])
# Out:
# 5

# %%
nums
# Out:
# [0, 0, 1, 1, 2, 3, 3, 3, 3]

# %% [markdown]
# ![image.png](attachment:image.png)
